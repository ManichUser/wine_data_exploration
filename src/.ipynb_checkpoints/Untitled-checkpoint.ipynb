# %%
import pandas as pd

df=pd.read_csv("../data/wine/wine.data")

df.columns=[
        "Classe", "Alcohol", "Malicacid", "Ash", "Alcalinity_of_ash", "Magnesium",
        "Total_phenols", "Flavanoids", "Nonflavanoid_phenols", "Proanthocyanins",
        "Color_intensity", "Hue", "0D280_0D315_of_diluted_wines", "Proline"
]
print("Apperçu des 10 premieres lignes")
print(df.head(10))
# Out:
# Apperçu des 10 premieres lignes
#    Classe  Alcohol  Malicacid   Ash  Alcalinity_of_ash  Magnesium  \
# 0       1    13.20       1.78  2.14               11.2        100
# 1       1    13.16       2.36  2.67               18.6        101
# 2       1    14.37       1.95  2.50               16.8        113
# 3       1    13.24       2.59  2.87               21.0        118
# 4       1    14.20       1.76  2.45               15.2        112
# 5       1    14.39       1.87  2.45               14.6         96
# 6       1    14.06       2.15  2.61               17.6        121
# 7       1    14.83       1.64  2.17               14.0         97
# 8       1    13.86       1.35  2.27               16.0         98
# 9       1    14.10       2.16  2.30               18.0        105
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
# 5           2.50        2.52                  0.30             1.98
# 6           2.60        2.51                  0.31             1.25
# 7           2.80        2.98                  0.29             1.98
# 8           2.98        3.15                  0.22             1.85
# 9           2.95        3.32                  0.22             2.38
#
#    Color_intensity   Hue  0D280_0D315_of_diluted_wines  Proline
# 0             4.38  1.05                          3.40     1050
# 1             5.68  1.03                          3.17     1185
# 2             7.80  0.86                          3.45     1480
# 3             4.32  1.04                          2.93      735
# 4             6.75  1.05                          2.85     1450
# 5             5.25  1.02                          3.58     1290
# 6             5.05  1.06                          3.58     1295
# 7             5.20  1.08                          2.85     1045
# 8             7.22  1.01                          3.55     1045
# 9             5.75  1.25                          3.17     1510

# %%
#comprehension du jeu de données
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Classe                        177 non-null    int64
#  1   Alcohol                       177 non-null    float64
#  2   Malicacid                     177 non-null    float64
#  3   Ash                           177 non-null    float64
#  4   Alcalinity_of_ash             177 non-null    float64
#  5   Magnesium                     177 non-null    int64
#  6   Total_phenols                 177 non-null    float64
#  7   Flavanoids                    177 non-null    float64
#  8   Nonflavanoid_phenols          177 non-null    float64
#  9   Proanthocyanins               177 non-null    float64
#  10  Color_intensity               177 non-null    float64
#  11  Hue                           177 non-null    float64
#  12  0D280_0D315_of_diluted_wines  177 non-null    float64
#  13  Proline                       177 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.5 KB
# None

# %%
#Statistique descriptive de nos données
print(df.describe())
# Out:
#            Classe     Alcohol   Malicacid         Ash  Alcalinity_of_ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total_phenols  Flavanoids  Nonflavanoid_phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.740000    1.200000              0.270000
# 50%     98.000000       2.350000    2.130000              0.340000
# 75%    107.000000       2.800000    2.860000              0.440000
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color_intensity         Hue  \
# count       177.000000       177.000000  177.000000
# mean          1.586949         5.054802    0.956983
# std           0.571545         2.324446    0.229135
# min           0.410000         1.280000    0.480000
# 25%           1.250000         3.210000    0.780000
# 50%           1.550000         4.680000    0.960000
# 75%           1.950000         6.200000    1.120000
# max           3.580000        13.000000    1.710000
#
#        0D280_0D315_of_diluted_wines      Proline
# count                    177.000000   177.000000
# mean                       2.604294   745.096045
# std                        0.705103   314.884046
# min                        1.270000   278.000000
# 25%                        1.930000   500.000000
# 50%                        2.780000   672.000000
# 75%                        3.170000   985.000000
# max                        4.000000  1680.000000

# %%
# Distribution des donnees pour chaque feature

import matplotlib.pyplot as plt
import seaborn as sns

# Liste des colonnes numériques
numerical_cols = ['Alcohol', 'Malicacid', 'Ash', 'Alcalinity_of_ash', 'Magnesium',
                  'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols', 'Proanthocyanins',
                  'Color_intensity', 'Hue', '0D280_0D315_of_diluted_wines', 'Proline']

# Créer des graphiques pour chaque colonne numérique
for col in numerical_cols:
    plt.figure(figsize=(15, 5))

    # Histogramme 
    plt.subplot(1, 2, 1) 
    sns.histplot(data=df, x=col, kde=True, bins=20, color='skyblue')
    plt.title(f'Histogramme de la distribution de {col}')
    plt.xlabel(col)

    # Box Plot (pour les outliers)
    plt.subplot(1, 2, 2) 
    sns.boxplot(data=df, y=col, color='lightcoral')
    plt.title(f'Box Plot de {col} (Outliers)')
    plt.ylabel(col)

    plt.tight_layout() 
    plt.show()
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10e761a80>>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 781, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:

# %%
# discrétisation par intervalles egales 
import numpy as np

# nombre d'intervalles et labels des intervalles
nb_groupes = 3
labels = ['Faible', 'Moyen', 'Élevé']

for col in numerical_cols:
    print(f"\n--- Analyse de la discrétisation pour : {col} ---")
    
    try:
        # 1. Effectuer la discrétisation par quantiles 
        qcut_result = pd.qcut(
            df[col],
            q=nb_groupes,
            duplicates='drop',
            retbins=True 
        )
        
        discretized_series = qcut_result[0]
        bins = qcut_result[1]
        
        # DataFrame en utilisant les labels
        df[col + '_Groupe'] = pd.qcut(
            df[col],
            q=nb_groupes,
            labels=labels,
            duplicates='drop'
        )

        print(f"Intervalles numériques réels (Seuils): {bins}")
        print(f"Correspondance des Groupes :")
        
        print(discretized_series.value_counts().sort_index())
        
        print(f"\nDistribution par étiquette Faible/Moyen/Élevé :")
        print(df[col + '_Groupe'].value_counts().sort_index())


    except ValueError as e:
        print(f"Erreur: Impossible de créer {nb_groupes} groupes pour {col}. (Peut-être pas assez de valeurs distinctes).")
        # On peut gérer ici le passage à q=2 si l'erreur se produit
        pass
# Out:
# --- Analyse de la discrétisation pour : Alcohol ---
# Intervalles numériques réels (Seuils): [11.03       12.51666667 13.48       14.83      ]
# Correspondance des Groupes :
# Alcohol
# (11.029, 12.517]    59
# (12.517, 13.48]     60
# (13.48, 14.83]      58
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Alcohol_Groupe
# Faible    59
# Moyen     60
# Élevé     58
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Malicacid ---
# Intervalles numériques réels (Seuils): [0.74       1.67       2.55333333 5.8       ]
# Correspondance des Groupes :
# Malicacid
# (0.739, 1.67]    60
# (1.67, 2.553]    58
# (2.553, 5.8]     59
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Malicacid_Groupe
# Faible    60
# Moyen     58
# Élevé     59
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Ash ---
# Intervalles numériques réels (Seuils): [1.36       2.27666667 2.48       3.23      ]
# Correspondance des Groupes :
# Ash
# (1.3590000000000002, 2.277]    59
# (2.277, 2.48]                  62
# (2.48, 3.23]                   56
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Ash_Groupe
# Faible    59
# Moyen     62
# Élevé     56
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Alcalinity_of_ash ---
# Intervalles numériques réels (Seuils): [10.6 18.  21.  30. ]
# Correspondance des Groupes :
# Alcalinity_of_ash
# (10.599, 18.0]    62
# (18.0, 21.0]      66
# (21.0, 30.0]      49
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Alcalinity_of_ash_Groupe
# Faible    62
# Moyen     66
# Élevé     49
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Magnesium ---
# Intervalles numériques réels (Seuils): [ 70.  92. 103. 162.]
# Correspondance des Groupes :
# Magnesium
# (69.999, 92.0]    63
# (92.0, 103.0]     58
# (103.0, 162.0]    56
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Magnesium_Groupe
# Faible    63
# Moyen     58
# Élevé     56
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Total_phenols ---
# Intervalles numériques réels (Seuils): [0.98       1.94333333 2.60333333 3.88      ]
# Correspondance des Groupes :
# Total_phenols
# (0.979, 1.943]    59
# (1.943, 2.603]    59
# (2.603, 3.88]     59
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Total_phenols_Groupe
# Faible    59
# Moyen     59
# Élevé     59
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Flavanoids ---
# Intervalles numériques réels (Seuils): [0.34       1.48666667 2.65       5.08      ]
# Correspondance des Groupes :
# Flavanoids
# (0.339, 1.487]    59
# (1.487, 2.65]     62
# (2.65, 5.08]      56
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Flavanoids_Groupe
# Faible    59
# Moyen     62
# Élevé     56
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Nonflavanoid_phenols ---
# Intervalles numériques réels (Seuils): [0.13 0.29 0.42 0.66]
# Correspondance des Groupes :
# Nonflavanoid_phenols
# (0.129, 0.29]    66
# (0.29, 0.42]     55
# (0.42, 0.66]     56
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Nonflavanoid_phenols_Groupe
# Faible    66
# Moyen     55
# Élevé     56
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Proanthocyanins ---
# Intervalles numériques réels (Seuils): [0.41       1.35       1.81333333 3.58      ]
# Correspondance des Groupes :
# Proanthocyanins
# (0.409, 1.35]    63
# (1.35, 1.813]    55
# (1.813, 3.58]    59
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Proanthocyanins_Groupe
# Faible    63
# Moyen     55
# Élevé     59
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Color_intensity ---
# Intervalles numériques réels (Seuils): [ 1.28        3.72666667  5.61666667 13.        ]
# Correspondance des Groupes :
# Color_intensity
# (1.2790000000000001, 3.727]    59
# (3.727, 5.617]                 59
# (5.617, 13.0]                  59
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Color_intensity_Groupe
# Faible    59
# Moyen     59
# Élevé     59
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Hue ---
# Intervalles numériques réels (Seuils): [0.48 0.87 1.07 1.71]
# Correspondance des Groupes :
# Hue
# (0.479, 0.87]    60
# (0.87, 1.07]     61
# (1.07, 1.71]     56
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Hue_Groupe
# Faible    60
# Moyen     61
# Élevé     56
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : 0D280_0D315_of_diluted_wines ---
# Intervalles numériques réels (Seuils): [1.27       2.29       3.02333333 4.        ]
# Correspondance des Groupes :
# 0D280_0D315_of_diluted_wines
# (1.2690000000000001, 2.29]    59
# (2.29, 3.023]                 59
# (3.023, 4.0]                  59
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# 0D280_0D315_of_diluted_wines_Groupe
# Faible    59
# Moyen     59
# Élevé     59
# Name: count, dtype: int64
#
# --- Analyse de la discrétisation pour : Proline ---
# Intervalles numériques réels (Seuils): [ 278.          556.66666667  831.66666667 1680.        ]
# Correspondance des Groupes :
# Proline
# (277.999, 556.667]    59
# (556.667, 831.667]    59
# (831.667, 1680.0]     59
# Name: count, dtype: int64
#
# Distribution par étiquette Faible/Moyen/Élevé :
# Proline_Groupe
# Faible    59
# Moyen     59
# Élevé     59
# Name: count, dtype: int64

# %%
# sns.pairplot(
#     df,
#     vars=numerical_cols, # Les colonnes à inclure
#     hue='Classe',        # Colore les points selon la variable cible
#     diag_kind='kde'      # Utiliser une estimation de densité lissée (KDE) sur la diagonale
# )

# plt.suptitle("Matrice de Nuages de Points (Pair Plot) par Classe de Vin", y=1.02)
# plt.show()
reduced_cols = ['Alcohol', 'Flavanoids', 'Total_phenols', 'Color_intensity']
sns.pairplot(
    df,
    vars=reduced_cols, 
    hue='Classe',
    diag_kind='kde'
)

# %%
# 1. Calculer la matrice de corrélation
correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(10, 8))

# 2. Créer la Heatmap
sns.heatmap(
    correlation_matrix,
    annot=True, # Afficher les valeurs numériques de corrélation
    cmap='coolwarm', # Palette de couleurs (rouge pour négatif, bleu pour positif)
    fmt=".2f", # Formatage à 2 décimales
    linewidths=.5, # Lignes de séparation
    cbar=True
)

plt.title("Corrélations entre Caractéristiques")
plt.show()
